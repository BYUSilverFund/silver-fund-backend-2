# %%
from services.service import Service
from query.query import Query
import json

# %%
# Parameters
fund = 'undergrad'
ticker = 'VIRT'
start='2023-07-05'
end='2024-07-05'

# %%
service = Service()
query = Query()

# %%
res = service.holding_summary(fund,ticker,start,end)

res = json.loads(res)

res
# Out:
# {'ticker': 'VIRT',
#  'active': False,
#  'shares': 0,
#  'initial_weight': 0.0464,
#  'current_weight': 0,
#  'price': 22.51,
#  'total_return': 26.67,
#  'total_div_return': 30.07,
#  'holding_period_return': 27.65,
#  'dividends': 1214.4,
#  'alpha': 0.14,
#  'beta': 0.3}

# %%
df = query.get_holding_df(fund,ticker,start,end)

df
# Out:
#           date       fund ticker                         name  weight_open  \
# 0   2023-10-13  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.045479
# 1   2023-10-16  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.046385
# 2   2023-10-17  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.047162
# 3   2023-10-18  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.047297
# 4   2023-10-19  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.047319
# ..         ...        ...    ...                          ...          ...
# 136 2024-05-06  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.050405
# 137 2024-05-07  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.050353
# 138 2024-05-08  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.049507
# 139 2024-05-09  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.049445
# 140 2024-05-10  undergrad   VIRT  VIRTU FINANCIAL INC-CLASS A     0.050027
#
# ...
